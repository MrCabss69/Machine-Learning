# %% [markdown]
# # ¿Cuánto cree la IA que vale tu casa? - Parte II
#
# En el capítulo introductorio hicimos un repaso a las bases matemáticas del ajuste de funciones, y la optimización de los parámetros, y en el siguiente vimos cómo preparar los datos para el entrenamiento con modelos de IA, creo que ya es momento que nos metamos un poco más en materia y empezemos con Keras, una librería disponible en Python, sencilla de usar, y muy potente.
#
# Pero ehhhhh! Alto ahí! Queda lo más importante, antes de empezar, tendremos que explicar un poco más a fondo es una red neuronal artifical, ¿no?

# %% [markdown]
# ![full_rnn.png](attachment:full_rnn.png)

# %% [markdown]
# ## Redes Neuronales

# %% [markdown]
# #### Funciones de activación
# Se utilizan en las neuronas para introducir no linealidades en el modelo. Estas funciones determinan si una neurona se activa o no, es decir, si envía una señal más allá de cierto umbral.
#
# #### Pesos internos
# Son parámetros ajustables en una red neuronal que se utilizan para ponderar las entradas y determinar la salida de cada neurona. Durante el entrenamiento, estos pesos se ajustan para minimizar una función de pérdida y mejorar el rendimiento del modelo.
#
# #### Neuronas
# Las neuronas son las unidades básicas de procesamiento en una red neuronal. Cada neurona toma entradas, realiza una operación en ellas y produce una salida.
#
# ![neuron.png](attachment:neuron.png)

# %% [markdown]
# Una forma simple de definir una red neuronal es como un conjunto de operaciones matemáticas aplicadas de forma secuencial y reiterada, con el objetivo de mejorar unos parámetros, y ajustar mejor una función de pérdida. Esta es una generalización que debe ser matizada, pero puede dar una idea más intuitiva de cómo funcionan internamente los modelos.

# %% [markdown]
# ## Construyendo un modelo con Keras para predecir el precio de la vivienda

# %% [markdown]
# #### Importar librerías

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# #### Cargar datos preprocesados

# %%
train_df = pd.read_csv('train.csv')  
test_df = pd.read_csv('test.csv')
val_df = pd.read_csv('val.csv')

# %% [markdown]
# #### Separar características

# %%
X_train = train_df['area'].values.reshape(-1, 1) 
y_train = train_df['price'].values

X_val = val_df['area'].values.reshape(-1, 1)
y_val = val_df['price'].values

X_test = test_df['area'].values.reshape(-1, 1)
y_test = test_df['price'].values

# %% [markdown]
# #### Definir el modelo

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# - Número de capas ocultas: 1
# - Número de neuronas en la capa: 8 
# - Función de activación: RELU
# - Optimizador: Adam
# - Función de Pérdia: MSE

model = Sequential()
model.add(Dense(units=8, activation='relu', input_shape=(1,)))
model.add(Dense(units=1))
model.compile(optimizer='adam', loss='mean_squared_error')
# Out:
# 2024-03-15 17:43:44.750897: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-03-15 17:43:44.827617: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-03-15 17:43:44.828336: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-15 17:43:45.743923: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# #### Entrenamiento

# %%
history = model.fit(X_train, y_train, epochs=100, validation_data=(X_val, y_val), verbose=1)
test_loss = model.evaluate(X_test, y_test)
# Out:
# Epoch 1/100
# 8/8 [==============================] - 1s 18ms/step - loss: 0.8067 - val_loss: 0.7558
# Epoch 2/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.7812 - val_loss: 0.7317
# Epoch 3/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.7571 - val_loss: 0.7105
# Epoch 4/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.7361 - val_loss: 0.6918
# Epoch 5/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.7184 - val_loss: 0.6748
# Epoch 6/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.7006 - val_loss: 0.6605
# Epoch 7/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.6872 - val_loss: 0.6475
# Epoch 8/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6741 - val_loss: 0.6365
# Epoch 9/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6625 - val_loss: 0.6274
# Epoch 10/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.6540 - val_loss: 0.6189
# Epoch 11/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.6450 - val_loss: 0.6121
# Epoch 12/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.6382 - val_loss: 0.6062
# Epoch 13/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6319 - val_loss: 0.6011
# Epoch 14/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6263 - val_loss: 0.5971
# Epoch 15/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.6222 - val_loss: 0.5935
# Epoch 16/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6194 - val_loss: 0.5904
# Epoch 17/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6156 - val_loss: 0.5879
# Epoch 18/100
# 8/8 [==============================] - 0s 7ms/step - loss: 0.6128 - val_loss: 0.5860
# Epoch 19/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6114 - val_loss: 0.5841
# Epoch 20/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6092 - val_loss: 0.5827
# Epoch 21/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.6069 - val_loss: 0.5815
# Epoch 22/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6059 - val_loss: 0.5803
# Epoch 23/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6051 - val_loss: 0.5795
# Epoch 24/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6035 - val_loss: 0.5787
# Epoch 25/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.6023 - val_loss: 0.5778
# Epoch 26/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.6015 - val_loss: 0.5770
# Epoch 27/100
# 8/8 [==============================] - 0s 7ms/step - loss: 0.6006 - val_loss: 0.5763
# Epoch 28/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6000 - val_loss: 0.5756
# Epoch 29/100
# 8/8 [==============================] - 0s 7ms/step - loss: 0.5993 - val_loss: 0.5750
# Epoch 30/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5988 - val_loss: 0.5744
# Epoch 31/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5986 - val_loss: 0.5735
# Epoch 32/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5977 - val_loss: 0.5731
# Epoch 33/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5970 - val_loss: 0.5727
# Epoch 34/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5965 - val_loss: 0.5722
# Epoch 35/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5962 - val_loss: 0.5719
# Epoch 36/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5958 - val_loss: 0.5713
# Epoch 37/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5954 - val_loss: 0.5706
# Epoch 38/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5950 - val_loss: 0.5702
# Epoch 39/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5947 - val_loss: 0.5699
# Epoch 40/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5942 - val_loss: 0.5696
# Epoch 41/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5939 - val_loss: 0.5688
# Epoch 42/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5935 - val_loss: 0.5685
# Epoch 43/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5934 - val_loss: 0.5679
# Epoch 44/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5931 - val_loss: 0.5674
# Epoch 45/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5929 - val_loss: 0.5674
# Epoch 46/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5924 - val_loss: 0.5672
# Epoch 47/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5922 - val_loss: 0.5669
# Epoch 48/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5921 - val_loss: 0.5666
# Epoch 49/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5919 - val_loss: 0.5658
# Epoch 50/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5914 - val_loss: 0.5657
# Epoch 51/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5911 - val_loss: 0.5654
# Epoch 52/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5909 - val_loss: 0.5651
# Epoch 53/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5905 - val_loss: 0.5648
# Epoch 54/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5903 - val_loss: 0.5644
# Epoch 55/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5898 - val_loss: 0.5642
# Epoch 56/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5897 - val_loss: 0.5637
# Epoch 57/100
# 8/8 [==============================] - 0s 13ms/step - loss: 0.5896 - val_loss: 0.5634
# Epoch 58/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5892 - val_loss: 0.5631
# Epoch 59/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5890 - val_loss: 0.5628
# Epoch 60/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5887 - val_loss: 0.5626
# Epoch 61/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5885 - val_loss: 0.5623
# Epoch 62/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5887 - val_loss: 0.5617
# Epoch 63/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5882 - val_loss: 0.5618
# Epoch 64/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5882 - val_loss: 0.5618
# Epoch 65/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5883 - val_loss: 0.5610
# Epoch 66/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5874 - val_loss: 0.5608
# Epoch 67/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5880 - val_loss: 0.5612
# Epoch 68/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5871 - val_loss: 0.5607
# Epoch 69/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5869 - val_loss: 0.5602
# Epoch 70/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5870 - val_loss: 0.5596
# Epoch 71/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5864 - val_loss: 0.5596
# Epoch 72/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5865 - val_loss: 0.5593
# Epoch 73/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5864 - val_loss: 0.5594
# Epoch 74/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5859 - val_loss: 0.5592
# Epoch 75/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5858 - val_loss: 0.5587
# Epoch 76/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5856 - val_loss: 0.5584
# Epoch 77/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5857 - val_loss: 0.5584
# Epoch 78/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5851 - val_loss: 0.5580
# Epoch 79/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5852 - val_loss: 0.5573
# Epoch 80/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5849 - val_loss: 0.5571
# Epoch 81/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5848 - val_loss: 0.5571
# Epoch 82/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5849 - val_loss: 0.5564
# Epoch 83/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5848 - val_loss: 0.5565
# Epoch 84/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5843 - val_loss: 0.5565
# Epoch 85/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5841 - val_loss: 0.5558
# Epoch 86/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5843 - val_loss: 0.5551
# Epoch 87/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5837 - val_loss: 0.5549
# Epoch 88/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5835 - val_loss: 0.5550
# Epoch 89/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5833 - val_loss: 0.5549
# Epoch 90/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5837 - val_loss: 0.5554
# Epoch 91/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5838 - val_loss: 0.5542
# Epoch 92/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5830 - val_loss: 0.5541
# Epoch 93/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5830 - val_loss: 0.5543
# Epoch 94/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5825 - val_loss: 0.5539
# Epoch 95/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5824 - val_loss: 0.5536
# Epoch 96/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5822 - val_loss: 0.5533
# Epoch 97/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5820 - val_loss: 0.5531
# Epoch 98/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5818 - val_loss: 0.5529
# Epoch 99/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5820 - val_loss: 0.5523
# Epoch 100/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5815 - val_loss: 0.5524
# 6/6 [==============================] - 0s 1ms/step - loss: 0.8769

# %% [markdown]
# #### Visualización de resultados

# %%
# Predicciones del modelo
y_pred = model.predict(X_test)

# Gráfico de dispersión de precios reales vs. predicciones
plt.figure(figsize=(10, 6))
plt.scatter(X_test, y_test, label='Reales')
plt.scatter(X_test, y_pred, label='Predicciones')
plt.title('Precios Reales vs. Predicciones')
plt.xlabel('Área')
plt.ylabel('Precio')
plt.legend()
plt.show()

# Histograma de precios reales vs. predicciones
plt.figure(figsize=(10, 6))
plt.hist(y_test, bins=20, alpha=0.5, label='Reales')
plt.hist(y_pred, bins=20, alpha=0.5, label='Predicciones')
plt.title('Distribución de Precios Reales vs. Predicciones')
plt.xlabel('Precio')
plt.ylabel('Frecuencia')
plt.legend()
plt.show()


print(f'Pérdida en los datos de prueba: {test_loss}')
# Out:
# 6/6 [==============================] - 0s 1ms/step
# Pérdida en los datos de prueba: 0.8768940567970276

# %% [markdown]
# ## Expermentando con distintas funciones de activación en la capa de salida

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

model = Sequential()
model.add(Dense(units=8, activation='relu', input_shape=(1,)))
model.add(Dense(units=1, activation='tanh'))                                    # Aplicación de tanh en la capa de salida
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
history = model.fit(X_train, y_train, epochs=100, validation_data=(X_val, y_val), verbose=1)
test_loss = model.evaluate(X_test, y_test)
# Out:
# Epoch 1/100
# 8/8 [==============================] - 1s 20ms/step - loss: 0.7063 - val_loss: 0.6670
# Epoch 2/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6881 - val_loss: 0.6494
# Epoch 3/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6722 - val_loss: 0.6331
# Epoch 4/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6574 - val_loss: 0.6188
# Epoch 5/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.6438 - val_loss: 0.6067
# Epoch 6/100
# 8/8 [==============================] - 0s 7ms/step - loss: 0.6338 - val_loss: 0.5956
# Epoch 7/100
# 8/8 [==============================] - 0s 9ms/step - loss: 0.6235 - val_loss: 0.5866
# Epoch 8/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6160 - val_loss: 0.5782
# Epoch 9/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.6085 - val_loss: 0.5714
# Epoch 10/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6029 - val_loss: 0.5651
# Epoch 11/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5978 - val_loss: 0.5598
# Epoch 12/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5934 - val_loss: 0.5554
# Epoch 13/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5900 - val_loss: 0.5517
# Epoch 14/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5869 - val_loss: 0.5487
# Epoch 15/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5842 - val_loss: 0.5463
# Epoch 16/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5824 - val_loss: 0.5441
# Epoch 17/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5809 - val_loss: 0.5419
# Epoch 18/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5791 - val_loss: 0.5403
# Epoch 19/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5779 - val_loss: 0.5389
# Epoch 20/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.5766 - val_loss: 0.5379
# Epoch 21/100
# 8/8 [==============================] - 0s 8ms/step - loss: 0.5756 - val_loss: 0.5370
# Epoch 22/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5751 - val_loss: 0.5361
# Epoch 23/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5741 - val_loss: 0.5353
# Epoch 24/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5734 - val_loss: 0.5348
# Epoch 25/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5729 - val_loss: 0.5343
# Epoch 26/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5724 - val_loss: 0.5338
# Epoch 27/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5721 - val_loss: 0.5334
# Epoch 28/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5715 - val_loss: 0.5331
# Epoch 29/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5712 - val_loss: 0.5327
# Epoch 30/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5710 - val_loss: 0.5323
# Epoch 31/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5706 - val_loss: 0.5321
# Epoch 32/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5705 - val_loss: 0.5318
# Epoch 33/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5702 - val_loss: 0.5316
# Epoch 34/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5700 - val_loss: 0.5315
# Epoch 35/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5700 - val_loss: 0.5312
# Epoch 36/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5699 - val_loss: 0.5311
# Epoch 37/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5698 - val_loss: 0.5311
# Epoch 38/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5696 - val_loss: 0.5308
# Epoch 39/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5694 - val_loss: 0.5307
# Epoch 40/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5697 - val_loss: 0.5308
# Epoch 41/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5694 - val_loss: 0.5305
# Epoch 42/100
# 8/8 [==============================] - 0s 7ms/step - loss: 0.5692 - val_loss: 0.5304
# Epoch 43/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5691 - val_loss: 0.5303
# Epoch 44/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5690 - val_loss: 0.5302
# Epoch 45/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5691 - val_loss: 0.5302
# Epoch 46/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5690 - val_loss: 0.5301
# Epoch 47/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5690 - val_loss: 0.5300
# Epoch 48/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5690 - val_loss: 0.5299
# Epoch 49/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5689 - val_loss: 0.5298
# Epoch 50/100
# 8/8 [==============================] - 0s 9ms/step - loss: 0.5688 - val_loss: 0.5298
# Epoch 51/100
# 8/8 [==============================] - 0s 7ms/step - loss: 0.5688 - val_loss: 0.5298
# Epoch 52/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5688 - val_loss: 0.5298
# Epoch 53/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5689 - val_loss: 0.5297
# Epoch 54/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5688 - val_loss: 0.5298
# Epoch 55/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5687 - val_loss: 0.5297
# Epoch 56/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5687 - val_loss: 0.5296
# Epoch 57/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5686 - val_loss: 0.5296
# Epoch 58/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5687 - val_loss: 0.5297
# Epoch 59/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5688 - val_loss: 0.5297
# Epoch 60/100
# 8/8 [==============================] - 0s 8ms/step - loss: 0.5686 - val_loss: 0.5296
# Epoch 61/100
# 8/8 [==============================] - 0s 7ms/step - loss: 0.5688 - val_loss: 0.5295
# Epoch 62/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5689 - val_loss: 0.5296
# Epoch 63/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5687 - val_loss: 0.5294
# Epoch 64/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5687 - val_loss: 0.5294
# Epoch 65/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5686 - val_loss: 0.5293
# Epoch 66/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5688 - val_loss: 0.5295
# Epoch 67/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5686 - val_loss: 0.5293
# Epoch 68/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5685 - val_loss: 0.5292
# Epoch 69/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5685 - val_loss: 0.5292
# Epoch 70/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5686 - val_loss: 0.5293
# Epoch 71/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5685 - val_loss: 0.5291
# Epoch 72/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5685 - val_loss: 0.5291
# Epoch 73/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5685 - val_loss: 0.5292
# Epoch 74/100
# 8/8 [==============================] - 0s 7ms/step - loss: 0.5685 - val_loss: 0.5291
# Epoch 75/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5685 - val_loss: 0.5290
# Epoch 76/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5686 - val_loss: 0.5289
# Epoch 77/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5687 - val_loss: 0.5292
# Epoch 78/100
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5685 - val_loss: 0.5291
# Epoch 79/100
# 8/8 [==============================] - 0s 7ms/step - loss: 0.5685 - val_loss: 0.5290
# Epoch 80/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5684 - val_loss: 0.5289
# Epoch 81/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5684 - val_loss: 0.5289
# Epoch 82/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5685 - val_loss: 0.5289
# Epoch 83/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5684 - val_loss: 0.5288
# Epoch 84/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5684 - val_loss: 0.5288
# Epoch 85/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5684 - val_loss: 0.5288
# Epoch 86/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5684 - val_loss: 0.5289
# Epoch 87/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5685 - val_loss: 0.5287
# Epoch 88/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5683 - val_loss: 0.5287
# Epoch 89/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5685 - val_loss: 0.5289
# Epoch 90/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5685 - val_loss: 0.5289
# Epoch 91/100
# 8/8 [==============================] - 0s 7ms/step - loss: 0.5683 - val_loss: 0.5288
# Epoch 92/100
# 8/8 [==============================] - 0s 8ms/step - loss: 0.5683 - val_loss: 0.5288
# Epoch 93/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5683 - val_loss: 0.5287
# Epoch 94/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5683 - val_loss: 0.5287
# Epoch 95/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5683 - val_loss: 0.5286
# Epoch 96/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5685 - val_loss: 0.5288
# Epoch 97/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5683 - val_loss: 0.5286
# Epoch 98/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.5683 - val_loss: 0.5286
# Epoch 99/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5683 - val_loss: 0.5286
# Epoch 100/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5684 - val_loss: 0.5287
# 6/6 [==============================] - 0s 1ms/step - loss: 0.9082

# %%
# Predicciones del modelo
y_pred = model.predict(X_test)

# Gráfico de dispersión de precios reales vs. predicciones
plt.figure(figsize=(10, 6))
plt.scatter(X_test, y_test, label='Reales')
plt.scatter(X_test, y_pred, label='Predicciones')
plt.title('Precios Reales vs. Predicciones')
plt.xlabel('Área')
plt.ylabel('Precio')
plt.legend()
plt.show()

# Histograma de precios reales vs. predicciones
plt.figure(figsize=(10, 6))
plt.hist(y_test, bins=20, alpha=0.5, label='Reales')
plt.hist(y_pred, bins=20, alpha=0.5, label='Predicciones')
plt.title('Distribución de Precios Reales vs. Predicciones')
plt.xlabel('Precio')
plt.ylabel('Frecuencia')
plt.legend()
plt.show()

print(f'Pérdida en los datos de prueba: {test_loss}')
# Out:
# 6/6 [==============================] - 0s 1ms/step
# Pérdida en los datos de prueba: 0.9082147479057312
